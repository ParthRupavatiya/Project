# %% [markdown]
# # HR Analytics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#import dataset
df = pd.read_csv("HR Employee Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#check columns name
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#check null values and data types of each attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# No null value present in our data

# %% [markdown]
# ## Univariate analysis

# %%
df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# 237 employees resigned out of 1470 employees.

# %%
df["Gender"].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# There is more male than female in our dataset.

# %%
df["BusinessTravel"].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# Most of the employees are travel rarely.

# %%
df["Department"].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# most of the Employees work in R&D department.

# %%
df["EducationField"].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
df["JobRole"].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# Most of the employees jobrole is Sales Executive than other jobroles.

# %%
df["MaritalStatus"].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# Most of the employees are married in this company.

# %%
df["Over18"].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %% [markdown]
# All of the employees age are over 18.

# %%
df["OverTime"].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# Most of the employees don't go for overtime working.

# %%
sns.violinplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# Most of the employees age is between 28 to 38 years.

# %%
sns.histplot(df["DistanceFromHome"])
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Count'>

# %% [markdown]
# Most of the employees live near to their workplace.

# %%
sns.countplot(df["EnvironmentSatisfaction"])
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %% [markdown]
# Most of the employees are satisfied with their work environment.

# %%
sns.countplot(df["JobInvolvement"])
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %% [markdown]
# Mojor of the employee have high job involvement.

# %%
sns.countplot(df["JobLevel"])
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# Major of the employee have low job level.

# %%
sns.countplot(df["JobSatisfaction"])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# Employees of the company have hihg job satisfaction.

# %%
sns.violinplot(df["MonthlyIncome"])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %% [markdown]
# Major of the employee have low salary.

# %%
sns.countplot(df["PerformanceRating"])
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='count'>

# %% [markdown]
# Mojor of the employees have performance rating of three.

# %%
sns.countplot(df["RelationshipSatisfaction"])
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='count'>

# %% [markdown]
# Employees have high relationship satisfaction.

# %%
sns.violinplot(df["YearsAtCompany"])
# Out:
# <AxesSubplot:xlabel='YearsAtCompany'>

# %% [markdown]
# Most of the employees have total working years at the IBM are between 1 to 10 years.

# %%
sns.countplot(df["YearsWithCurrManager"])
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='count'>

# %% [markdown]
# Most of the employees working with same manager for less than five years.`

# %% [markdown]
# ## Bivariate analysis

# %%
#check correlation of every attributes.
plt.figure(figsize=(24,20))
sns.heatmap(df.corr(),annot=True,linewidth=0.7,linecolor="black")
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap, we can see positive and negative correlation of attributes with each other.
#
# Age,job level, monthly income and years at company are highly positive correlated with total working years.
#
# Years in current role and Years with current manager is highly positive correlated with years at company.

# %%
sns.scatterplot(x="JobLevel",y="TotalWorkingYears",data=df)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='TotalWorkingYears'>

# %%
sns.scatterplot(x="MonthlyIncome",y="TotalWorkingYears",data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='TotalWorkingYears'>

# %%
sns.factorplot(x="Attrition",y="DistanceFromHome",data=df,kind="bar")

# %% [markdown]
# Most of the employees who leave their job is travel far from home.

# %%
sns.factorplot(x="Attrition",col="EnvironmentSatisfaction",data=df,kind="count")

# %% [markdown]
# Employees with low environment satisfaction leave their job.

# %%
sns.factorplot(x="Attrition",col="JobSatisfaction",data=df,kind="count")

# %% [markdown]
# Employees with low job satisfaction resigned their job.

# %%
sns.factorplot(x="Attrition",y="MonthlyIncome",data=df,kind="bar")

# %% [markdown]
# Employees who have low income had leave their job.

# %%
sns.factorplot(x="Attrition",y="TotalWorkingYears",data=df,kind="bar")

# %% [markdown]
# employees with low work experience resigned their job.

# %%
sns.factorplot(x="Attrition",y="YearsAtCompany",data=df,kind="bar")

# %% [markdown]
# Employees who resigned their job have working at IBM for less than 5.5 years.

# %%
sns.barplot(x=df["Gender"],y=df.Attrition=="Yes")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Attrition'>

# %% [markdown]
# Most of the employees who leave their job is male

# %%
sns.barplot(x=df["BusinessTravel"],y=df.Attrition=="Yes")
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Attrition'>

# %% [markdown]
# Employees who travel frequently have high attrition rate.

# %%
sns.barplot(x=df["Department"],y=df.Attrition=="Yes")
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Attrition'>

# %% [markdown]
# Sales and Human Resources department have high attrition rate compared to R&D department.

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df["EducationField"],y=df.Attrition=="Yes")
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Attrition'>

# %% [markdown]
# Employees who have educational bacground of marketing,technical degree, human resources have high attrition rate.

# %%
sns.barplot(x=df["MaritalStatus"],y=df.Attrition=="Yes")
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Attrition'>

# %% [markdown]
# Employees with single marital status have high attrition rate.

# %%
#drop some attributes who doesn't affect our dataset and some columns have only one value.
df = df.drop(["EmployeeCount","StandardHours","Over18","EmployeeNumber"],axis=1)

# %%
#convert catagorical data into numerical data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Attrition"] = le.fit_transform(df["Attrition"])
df["Gender"] = le.fit_transform(df["Gender"])
df["MaritalStatus"] = le.fit_transform(df["MaritalStatus"])
df["OverTime"] = le.fit_transform(df["OverTime"])

df = pd.get_dummies(df,drop_first=True)
df.shape
# Out:
# (1470, 44)

# %% [markdown]
# ## Handling outliers

# %%
#check and remove outliers with zscore
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold=3
print(np.where(z>3))
# Out:
# (array([   2,    8,   15,   18,   20,   20,   21,   22,   25,   25,   28,
#          29,   31,   33,   33,   36,   37,   40,   45,   45,   45,   51,
#          55,   59,   60,   62,   62,   62,   63,   64,   64,   65,   66,
#          75,   77,   77,   78,   79,   84,   85,   85,   86,   86,   95,
#          95,   96,   98,   98,  100,  103,  105,  106,  110,  112,  116,
#         117,  119,  123,  123,  123,  123,  125,  126,  126,  126,  127,
#         128,  129,  134,  135,  136,  139,  142,  145,  147,  152,  153,
#         155,  155,  156,  159,  165,  170,  171,  171,  178,  182,  184,
#         186,  187,  187,  187,  188,  190,  190,  190,  192,  194,  197,
#         198,  199,  199,  200,  200,  201,  211,  213,  214,  215,  217,
#         218,  222,  222,  224,  226,  231,  231,  231,  231,  232,  233,
#         235,  237,  237,  237,  238,  243,  244,  244,  245,  247,  249,
#         250,  251,  255,  257,  262,  263,  263,  270,  270,  270,  271,
# ...

# %%
df_new = df[(z<3).all(axis=1)]
df_new
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0      41          1       1102                 1          2
# 1      49          0        279                 8          1
# 3      33          0       1392                 3          4
# 4      27          0        591                 2          1
# 5      32          0       1005                 2          2
# ...   ...        ...        ...               ...        ...
# 1462   39          0        722                24          1
# 1465   36          0        884                23          2
# 1466   39          0        613                 6          1
# 1468   49          0       1023                 2          3
# 1469   34          0        628                 8          3
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2       0          94               3         2
# 1                           3       1          61               2         2
# ...

# %%
df.shape
# Out:
# (1470, 44)

# %%
percentage_loss = ((1470-832)/1470)*100
percentage_loss
# Out:
# 43.40136054421769

# %% [markdown]
# Here,percentage loss is more so we do not remove outliers using zscore and try IQR method.

# %%
#check and remove outliers by inter qurtile range.
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Age                                     13.00
# Attrition                                0.00
# DailyRate                              692.00
# DistanceFromHome                        12.00
# Education                                2.00
# EnvironmentSatisfaction                  2.00
# Gender                                   1.00
# HourlyRate                              35.75
# JobInvolvement                           1.00
# JobLevel                                 2.00
# JobSatisfaction                          2.00
# MaritalStatus                            1.00
# MonthlyIncome                         5468.00
# MonthlyRate                          12414.50
# NumCompaniesWorked                       3.00
# OverTime                                 1.00
# PercentSalaryHike                        6.00
# PerformanceRating                        0.00
# RelationshipSatisfaction                 2.00
# StockOptionLevel                         1.00
# ...

# %%
df_new1 = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_new1.shape)
# Out:
# (47, 44)

# %% [markdown]
# From above observation,percentage loss is very high so, we dont remove outliers by this method.

# %%
x = df.drop(["Attrition"],axis=1)
y = df["Attrition"]

# %% [markdown]
# ## Scaling data

# %%
#scaling data by standard scaler method with mean=zero and unit varience.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_t = sc.fit_transform(x)

# %%
# Dimension reduction by Principle Component Analysis method
from sklearn.decomposition import PCA
pca = PCA(n_components=31)
x_d = pca.fit_transform(x_t)

# %%
#split train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_d,y,test_size=0.20,random_state=42,stratify=y)

# %%
#check shape of train and test data
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1176, 31)
# (1176,)
# (294, 31)
# (294,)

# %% [markdown]
# ## Finding best model

# %%
#Find best model.our target varieble is attrition so it is classification problem.
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

model = [LogisticRegression(),GaussianNB(),DecisionTreeClassifier(),SVC(),KNeighborsClassifier()]

for m in model:
    m.fit(x_train,y_train)
    train = m.score(x_train,y_train)
    predm = m.predict(x_test)
    print("Accuracy of",m,"is:")
    print("Training accuracy is:",train)
    print("Accuracy score:",accuracy_score(y_test,predm)*100)
    print("confusion matrix:","\n",confusion_matrix(y_test,predm))
    print("classification report:","\n",classification_report(y_test,predm))
    print("\n")
# Out:
# Accuracy of LogisticRegression() is:
# Training accuracy is: 0.8937074829931972
# Accuracy score: 87.41496598639455
# confusion matrix:
#  [[240   7]
#  [ 30  17]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       247
#            1       0.71      0.36      0.48        47
#
#     accuracy                           0.87       294
#    macro avg       0.80      0.67      0.70       294
# weighted avg       0.86      0.87      0.86       294
#
#
#
# Accuracy of GaussianNB() is:
# Training accuracy is: 0.8647959183673469
# Accuracy score: 79.59183673469387
# confusion matrix:
#  [[223  24]
#  [ 36  11]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       247
#            1       0.31      0.23      0.27        47
#
#     accuracy                           0.80       294
# ...

# %% [markdown]
# Logistic Regreesion give good accuracy score with confusion matrix and classification report.

# %%
#Improve accuracy by bagging method using gridsearchcv
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
parameters = {'n_estimators':[50,100,150],'criterion':['gini','entropy']}
clf = GridSearchCV(rfc,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'gini', 'n_estimators': 100}

# %%
rfc = RandomForestClassifier(criterion='gini',n_estimators=100)
rfc.fit(x_train,y_train)
train = rfc.score(x_train,y_train)
predrfc = rfc.predict(x_test)
print("Training accuracy:",train)
print("Accuracy score:",accuracy_score(y_test,predrfc)*100)
print("confusion matrix:","\n",confusion_matrix(y_test,predrfc))
print("classification report:","\n",classification_report(y_test,predrfc))
# Out:
# Training accuracy: 1.0
# Accuracy score: 85.71428571428571
# confusion matrix:
#  [[246   1]
#  [ 41   6]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       247
#            1       0.86      0.13      0.22        47
#
#     accuracy                           0.86       294
#    macro avg       0.86      0.56      0.57       294
# weighted avg       0.86      0.86      0.81       294

# %%
#improve accuracy by boosting method using gridsearchcv
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(base_estimator=LogisticRegression())
ada.fit(x_train,y_train)
train = ada.score(x_train,y_train)
predada = ada.predict(x_test)
print("Training accuracy:",train)
print("Accuracy score:",accuracy_score(y_test,predada)*100)
print("confusion matrix:","\n",confusion_matrix(y_test,predada))
print("classification report:","\n",classification_report(y_test,predada))
# Out:
# Training accuracy: 0.8860544217687075
# Accuracy score: 86.39455782312925
# confusion matrix:
#  [[239   8]
#  [ 32  15]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       247
#            1       0.65      0.32      0.43        47
#
#     accuracy                           0.86       294
#    macro avg       0.77      0.64      0.68       294
# weighted avg       0.85      0.86      0.84       294

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
parameters = {'loss':['deviance','exponential'],'n_estimators':[50,100,150],'criterion':['friedman_mse','mse']}
clf = GridSearchCV(gbc,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'loss': 'deviance', 'n_estimators': 100}

# %%
gbc = GradientBoostingClassifier(criterion='friedman_mse',loss='deviance',n_estimators=100)
gbc.fit(x_train,y_train)
train = gbc.score(x_train,y_train)
predgbc = gbc.predict(x_test)
print("Training accuracy:",train)
print("Accuracy score:",accuracy_score(y_test,predgbc)*100)
print("confusion matrix:","\n",confusion_matrix(y_test,predgbc))
print("classification report:","\n",classification_report(y_test,predgbc))
# Out:
# Training accuracy: 0.9744897959183674
# Accuracy score: 83.33333333333334
# confusion matrix:
#  [[237  10]
#  [ 39   8]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       247
#            1       0.44      0.17      0.25        47
#
#     accuracy                           0.83       294
#    macro avg       0.65      0.56      0.58       294
# weighted avg       0.79      0.83      0.80       294

# %%
from xgboost import XGBClassifier
xg = XGBClassifier()
parameters = {'n_estimators':[50,100,200,250],'max_depth':[1,2,3,4],'learning_rate':[0.001,0.1,0.2,0.4,0.6],'booster':['gbtree','gblinear','dart'],'gamma':[0.01,0.1]}
clf = GridSearchCV(xg,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# [20:42:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:42:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:42:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
xg = XGBClassifier(booster='gblinear',learning_rate=0.1,max_depth=1,n_estimators=50,gamma=0.01)
xg.fit(x_train,y_train)
train = xg.score(x_train,y_train)
predxg = xg.predict(x_test)
print("Training accuracy:",train)
print("Accuracy score:",accuracy_score(y_test,predxg)*100)
print("confusion matrix:","\n",confusion_matrix(y_test,predxg))
print("classification report:","\n",classification_report(y_test,predxg))
# Out:
# [20:57:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { gamma, max_depth } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [20:57:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training accuracy: 0.8894557823129252
# Accuracy score: 88.09523809523809
# confusion matrix:
#  [[242   5]
#  [ 30  17]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       247
# ...

# %% [markdown]
# We get good accuracy with xgboost.

# %%
#check accuracy with cross-validation
from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(xg,x_d,y,cv=10)
print(accuracy)
print("Accuracy score of model with cross validation is:",accuracy.mean()*100)
# Out:
# [20:58:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { gamma, max_depth } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [20:58:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:58:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { gamma, max_depth } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
# ...

# %% [markdown]
# We get good accuracy score using xgboost and get good accuracy score using cross validation with xgboost.

# %%
#save best result
df1 = pd.DataFrame(predxg)
df1.to_csv("xg_HRanalytics.csv")

# %%
#save best model
import joblib
joblib.dump(xg,"xg_HRanalytics.obj")
# Out:
# ['xg_HRanalytics.obj']
